# %% [markdown]
# # Does it help to use local translation? Or is the test broken?
# A spainard translated a document for all spanish speakers (e.g., Mexican, Colombian, etc) to use. Company XYZ then saw that spainards converted at a higher rate than other users. Company XYZ thought this conversion derived from their local translation, so they tried local translations for each spanish speaking country. But these local translations seem to decrease conversion. Is this result real or did they mess something up?
# * **Is the test in fact negative?** ("it appears that the old version of the site with just one translation across Spain and LatAm performs better")
# * **Why might this be the case?**
# * **If I identify what's wrong:** generate algorithm to return FALSE if same problem happens in future and TRUE if results can be trusted

# %%
import numpy as np
import pandas as pd
from __future__ import division

# %%
test_table = pd.read_csv('Translation_Test/test_table.csv')
print test_table.shape
print test_table.columns
# Out:
# (453321, 9)
# Index([u'user_id', u'date', u'source', u'device', u'browser_language',
#        u'ads_channel', u'browser', u'conversion', u'test'],
#       dtype='object')

# %%
user_table = pd.read_csv('Translation_Test/user_table.csv')
print user_table.shape
print user_table.columns
# Out:
# (452867, 4)
# Index([u'user_id', u'sex', u'age', u'country'], dtype='object')

# %%
print test_table.head(2)
print test_table.dtypes
print user_table.head(2)
print user_table.dtypes
# Out:
#    user_id        date  source device browser_language ads_channel browser  \
# 0   315281  2015-12-03  Direct    Web               ES         NaN      IE
# 1   497851  2015-12-04     Ads    Web               ES      Google      IE
#
#    conversion  test
# 0           1     0
# 1           0     1
# user_id              int64
# date                object
# source              object
# device              object
# browser_language    object
# ads_channel         object
# browser             object
# conversion           int64
# test                 int64
# dtype: object
#    user_id sex  age    country
# 0   765821   M   20     Mexico
# 1   343561   F   27  Nicaragua
# user_id     int64
# sex        object
# age         int64
# country    object
# dtype: object

# %%
test_table[test_table['conversion'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [user_id, date, source, device, browser_language, ads_channel, browser, conversion, test]
# Index: []

# %% [markdown]
# ### What are the proportions of user conversion after test?

# %% [markdown]
# Ads should function independent of the site itself. Our interest concerns whether site translation made a difference, so leave out users who came to the site via "Ads" (i.e., keep "SEO" and "Direct").

# %%
test_table[test_table['source'] != "Ads"]
# Out:
#         user_id        date  source  device browser_language ads_channel  \
# 0        315281  2015-12-03  Direct     Web               ES         NaN
# 5        540675  2015-12-03  Direct  Mobile               ES         NaN
# 6        863394  2015-12-04     SEO  Mobile            Other         NaN
# 7        527287  2015-12-03  Direct     Web               EN         NaN
# 8        261625  2015-12-04  Direct  Mobile               ES         NaN
# 11        73335  2015-12-03     SEO     Web               ES         NaN
# 12       744811  2015-12-01     SEO  Mobile               ES         NaN
# 13       234023  2015-12-03     SEO     Web               ES         NaN
# 15       103879  2015-11-30  Direct  Mobile               ES         NaN
# 16       409295  2015-12-02  Direct     Web               ES         NaN
# 17       313345  2015-12-01     SEO     Web               ES         NaN
# 18       464816  2015-12-01  Direct     Web               ES         NaN
# 19       740007  2015-11-30     SEO     Web               ES         NaN
# 22       913301  2015-11-30  Direct  Mobile               ES         NaN
# 23       833933  2015-11-30     SEO     Web               ES         NaN
# 26       698306  2015-12-02     SEO  Mobile            Other         NaN
# 27       881703  2015-12-01     SEO  Mobile               EN         NaN
# 28       449365  2015-12-01  Direct     Web               EN         NaN
# 30       178310  2015-12-04     SEO  Mobile               ES         NaN
# 32       435134  2015-11-30     SEO     Web               ES         NaN
# 35       298244  2015-12-04  Direct  Mobile               ES         NaN
# 37       702037  2015-11-30  Direct     Web               ES         NaN
# 38       225549  2015-12-02     SEO     Web               ES         NaN
# 39       445468  2015-12-04     SEO  Mobile               ES         NaN
# 40       103330  2015-12-03  Direct  Mobile               ES         NaN
# 41       856477  2015-12-04     SEO  Mobile               EN         NaN
# 42       610992  2015-12-03     SEO     Web               EN         NaN
# 45       287339  2015-12-04  Direct     Web               ES         NaN
# 46       759619  2015-12-02  Direct     Web               ES         NaN
# 47       619566  2015-12-03  Direct     Web               ES         NaN
# ...         ...         ...     ...     ...              ...         ...
# 453262   486956  2015-12-02     SEO     Web               ES         NaN
# 453266   817076  2015-12-04  Direct  Mobile               ES         NaN
# 453267   928612  2015-12-01  Direct     Web               ES         NaN
# 453268   750195  2015-12-02  Direct  Mobile               ES         NaN
# 453269   574709  2015-11-30     SEO     Web               ES         NaN
# 453272   793369  2015-11-30     SEO     Web               ES         NaN
# 453275   325773  2015-12-03  Direct     Web            Other         NaN
# 453276   943808  2015-12-03  Direct     Web               ES         NaN
# 453277   475117  2015-12-02     SEO     Web               ES         NaN
# 453278   596170  2015-12-03     SEO     Web               ES         NaN
# 453283   238260  2015-12-03     SEO     Web               ES         NaN
# 453284   761297  2015-12-01     SEO     Web               ES         NaN
# 453285   424130  2015-12-01     SEO  Mobile               ES         NaN
# 453286   689957  2015-12-04  Direct  Mobile               ES         NaN
# 453289   576115  2015-12-02  Direct     Web               ES         NaN
# 453292   571940  2015-12-01     SEO     Web               ES         NaN
# 453295   853589  2015-12-03     SEO     Web               ES         NaN
# 453300   320177  2015-12-04  Direct     Web               ES         NaN
# 453301    18829  2015-12-03     SEO     Web               EN         NaN
# 453304   744029  2015-12-01  Direct     Web               ES         NaN
# 453306   652445  2015-12-02     SEO  Mobile               ES         NaN
# 453308   511898  2015-12-04     SEO     Web               ES         NaN
# 453309   692975  2015-12-03     SEO  Mobile               ES         NaN
# 453310   364818  2015-11-30     SEO     Web               ES         NaN
# 453311   411293  2015-12-04     SEO  Mobile               ES         NaN
# 453312   963759  2015-11-30     SEO  Mobile               ES         NaN
# 453313   177274  2015-11-30     SEO  Mobile               ES         NaN
# 453316   425010  2015-12-04     SEO     Web               ES         NaN
# 453317   826793  2015-12-01     SEO  Mobile               ES         NaN
# 453319   785224  2015-12-04     SEO  Mobile               ES         NaN
#
#             browser  conversion  test
# 0                IE           1     0
# 5       Android_App           0     1
# 6       Android_App           0     0
# 7            Chrome           0     0
# 8       Android_App           0     1
# 11               IE           0     1
# 12      Android_App           1     0
# 13           Chrome           0     0
# 15       Iphone_App           0     0
# 16          FireFox           0     1
# 17               IE           0     0
# 18          FireFox           0     0
# 19           Chrome           0     1
# 22       Iphone_App           0     0
# 23          FireFox           0     0
# 26      Android_App           0     1
# 27       Iphone_App           0     1
# 28           Chrome           0     0
# 30      Android_App           0     1
# 32           Chrome           0     0
# 35      Android_App           0     0
# 37          FireFox           0     0
# 38          FireFox           0     0
# 39      Android_App           0     0
# 40      Android_App           0     0
# 41      Android_App           0     0
# 42               IE           0     0
# 45               IE           0     0
# 46               IE           0     1
# 47               IE           0     0
# ...             ...         ...   ...
# 453262      FireFox           0     0
# 453266  Android_App           0     0
# 453267           IE           0     1
# 453268   Iphone_App           0     1
# 453269           IE           0     1
# 453272           IE           0     1
# 453275       Chrome           0     0
# 453276      FireFox           0     1
# 453277       Chrome           0     0
# 453278      FireFox           0     1
# 453283           IE           0     0
# 453284       Safari           0     0
# 453285  Android_App           0     1
# 453286  Android_App           0     1
# 453289           IE           0     0
# 453292      FireFox           1     1
# 453295       Chrome           0     1
# 453300       Chrome           0     0
# 453301       Chrome           0     0
# 453304       Safari           0     0
# 453306  Android_App           0     0
# 453308       Chrome           0     0
# 453309  Android_App           0     0
# 453310       Chrome           0     1
# 453311  Android_App           0     0
# 453312   Iphone_App           0     0
# 453313   Iphone_App           0     0
# 453316      FireFox           0     0
# 453317  Android_App           0     1
# 453319  Android_App           0     1
#
# [271444 rows x 9 columns]

# %%
test_table_noads = test_table[test_table['source'] != "Ads"]

# %%
user_table[user_table.user_id == test_table_noads.user_id.iloc[0]]
# Out:
#        user_id sex  age country
# 19877   315281   M   32   Spain

# %%
test_table_noads.head(2)
# Out:
#    user_id        date  source  device browser_language ads_channel  \
# 0   315281  2015-12-03  Direct     Web               ES         NaN
# 5   540675  2015-12-03  Direct  Mobile               ES         NaN
#
#        browser  conversion  test
# 0           IE           1     0
# 5  Android_App           0     1

# %% [markdown]
# #### Merge the tables with the additional variables, so I can analyze them

# %%
test_table_noads_merged = test_table_noads.merge(user_table, on='user_id', how='left')
test_table_noads_merged.head(3)
# Out:
#    user_id        date  source  device browser_language ads_channel  \
# 0   315281  2015-12-03  Direct     Web               ES         NaN
# 1   540675  2015-12-03  Direct  Mobile               ES         NaN
# 2   863394  2015-12-04     SEO  Mobile            Other         NaN
#
#        browser  conversion  test sex  age    country
# 0           IE           1     0   M   32      Spain
# 1  Android_App           0     1   F   22  Venezuela
# 2  Android_App           0     0   M   35     Mexico

# %% [markdown]
# ## Plot number of users by country and whether they are test or control
#
# #### (Then break those up into conversion or not)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()
plt.figure(figsize=(11, 8), facecolor='w', edgecolor='k')
sns.countplot(y='country', hue='test', data=test_table_noads_merged, palette='Set1')
plt.title('Users by country and Test group')
plt.show()

# %% [markdown]
# ### Interesting things about above plot
# * Big disparity in group size for each Uruguay and Argentina
# * Far more users in Mexico than other countries (just reflects population disparity)

# %%
plt.figure()
plt.figure(figsize=(11, 8), facecolor='w', edgecolor='k')
sns.countplot(y='country', hue='conversion', data=test_table_noads_merged[test_table_noads_merged['test'] == 1])
plt.title('Users in the test group by country and conversion')
plt.show()

# %% [markdown]
# Above plot suggests that within this test group there is much more "not conversion" than conversion

# %% [markdown]
# ## Use fisher's exact test to assess significance in 2 x 2
# (Converted x not converted, test x control)

# %% [markdown]
# ### First, check whether the control group shows significant difference:

# %%
from scipy import stats

# %%
n_control_notconv = test_table_noads_merged[(test_table_noads_merged['country'] != "Spain") & (test_table_noads_merged['test'] == 0) & (test_table_noads_merged['conversion']==0)].shape[0]
n_control_conv = test_table_noads_merged[(test_table_noads_merged['country'] != "Spain") & (test_table_noads_merged['test'] == 0) & (test_table_noads_merged['conversion']==1)].shape[0]
n_test_notconv = test_table_noads_merged[(test_table_noads_merged['test'] == 1) & (test_table_noads_merged['conversion']==0)].shape[0]
n_test_conv = test_table_noads_merged[(test_table_noads_merged['test'] == 1) & (test_table_noads_merged['conversion']==1)].shape[0]

# %%
stats.binom_test(n_control_conv, (n_control_conv+n_control_notconv), alternative="greater")
# Out:
# 0.99999999999999989

# %% [markdown]
# That p-value above is very non-significant. So there appears to be no conversion in the control group. (This is a sanity check. If the control group showed conversion there would be a whole issue here.)

# %% [markdown]
# Print the sizes of the converted and not converted in the test group:

# %%
print test_table_noads_merged[(test_table_noads_merged['test'] == 0) & (test_table_noads_merged['conversion']==1)].shape[0]
print test_table_noads_merged[(test_table_noads_merged['test'] == 0) & (test_table_noads_merged['conversion']==0)].shape[0]
# Out:
# 7806
# 134184

# %% [markdown]
# ### Does this test group show significantly greater conversion?

# %%
stats.binom_test(n_test_conv, (n_test_conv+n_test_notconv), alternative="greater")
# Out:
# 0.99999999999999989

# %% [markdown]
# Can't say that there is greater conversion in the test group.

# %% [markdown]
# ### Test whether greater conversion in test group than control
# (This should not signficantly differ)

# %%
oddsratio, pvalue = stats.fisher_exact([[n_test_conv, n_test_notconv], [n_control_conv, n_control_notconv]], alternative="greater")
print oddsratio
print pvalue
# Out:
# 0.778826987081
# 1.0

# %% [markdown]
# Above says there is not greater conversion in test group than control.

# %% [markdown]
# ### Because Argentina and Uruguay show imabalances in group sizes (see above plot), check whether dropping them gives different result

# %%
test_noarg_nougy = test_table_noads_merged[(test_table_noads_merged['country'] != "Spain") & (test_table_noads_merged['country'] != "Argentina") & (test_table_noads_merged['country'] != "Uruguay")]

# %%
n_control_notconv = test_noarg_nougy[(test_table_noads_merged['country'] != "Spain") & (test_noarg_nougy['test'] == 0) & (test_noarg_nougy['conversion']==0)].shape[0]
n_control_conv = test_noarg_nougy[(test_table_noads_merged['country'] != "Spain") & (test_noarg_nougy['test'] == 0) & (test_noarg_nougy['conversion']==1)].shape[0]
n_test_notconv = test_noarg_nougy[(test_noarg_nougy['test'] == 1) & (test_noarg_nougy['conversion']==0)].shape[0]
n_test_conv = test_noarg_nougy[(test_noarg_nougy['test'] == 1) & (test_noarg_nougy['conversion']==1)].shape[0]

# %%
stats.binom_test(n_control_conv, (n_control_conv+n_control_notconv), alternative="greater")
# Out:
# 0.99999999999999989

# %%
stats.binom_test(n_test_conv, (n_test_conv+n_test_notconv), alternative="greater")
# Out:
# 0.99999999999999989

# %%
oddsratio, pvalue = stats.fisher_exact([[n_test_conv, n_test_notconv], [n_control_conv, n_control_notconv]], alternative="greater")
print oddsratio
print pvalue
# Out:
# 1.00773386505
# 0.353868486747

# %%
test_noarg_nougy[(test_noarg_nougy['test'] == 0) & (test_noarg_nougy['conversion']==0)]
# Out:
#         user_id        date  source  device browser_language ads_channel  \
# 2        863394  2015-12-04     SEO  Mobile            Other         NaN
# 7        234023  2015-12-03     SEO     Web               ES         NaN
# 8        103879  2015-11-30  Direct  Mobile               ES         NaN
# 11       464816  2015-12-01  Direct     Web               ES         NaN
# 13       913301  2015-11-30  Direct  Mobile               ES         NaN
# 14       833933  2015-11-30     SEO     Web               ES         NaN
# 19       435134  2015-11-30     SEO     Web               ES         NaN
# 20       298244  2015-12-04  Direct  Mobile               ES         NaN
# 21       702037  2015-11-30  Direct     Web               ES         NaN
# 22       225549  2015-12-02     SEO     Web               ES         NaN
# 24       103330  2015-12-03  Direct  Mobile               ES         NaN
# 25       856477  2015-12-04     SEO  Mobile               EN         NaN
# 26       610992  2015-12-03     SEO     Web               EN         NaN
# 32       846916  2015-12-04  Direct     Web               ES         NaN
# 33       720929  2015-12-03     SEO  Mobile               ES         NaN
# 37       971271  2015-12-03  Direct  Mobile               EN         NaN
# 41       362282  2015-12-02     SEO  Mobile               EN         NaN
# 42       978095  2015-12-01  Direct     Web               ES         NaN
# 47       129023  2015-12-04     SEO  Mobile               ES         NaN
# 48       710397  2015-11-30     SEO     Web               ES         NaN
# 52       390307  2015-11-30  Direct  Mobile               EN         NaN
# 54       771142  2015-12-04     SEO     Web               ES         NaN
# 57       846393  2015-12-01  Direct     Web               ES         NaN
# 59       472007  2015-12-04  Direct     Web               ES         NaN
# 61       513083  2015-12-03     SEO     Web               ES         NaN
# 62       456022  2015-12-04     SEO  Mobile               ES         NaN
# 67       629672  2015-12-04     SEO     Web               ES         NaN
# 68       638428  2015-12-02  Direct  Mobile               ES         NaN
# 70       767646  2015-11-30     SEO     Web               ES         NaN
# 78       257196  2015-12-01     SEO  Mobile               ES         NaN
# ...         ...         ...     ...     ...              ...         ...
# 271366   331264  2015-12-01  Direct     Web               ES         NaN
# 271368   577453  2015-12-04  Direct     Web               ES         NaN
# 271372   901125  2015-12-01  Direct     Web               ES         NaN
# 271374   640247  2015-12-04     SEO  Mobile               ES         NaN
# 271375   497198  2015-12-04  Direct     Web               ES         NaN
# 271378   837039  2015-12-04  Direct  Mobile               ES         NaN
# 271381   764637  2015-12-04     SEO     Web               ES         NaN
# 271386   766513  2015-12-01     SEO     Web               ES         NaN
# 271387   815079  2015-12-04  Direct     Web               ES         NaN
# 271390   688381  2015-12-04     SEO     Web               ES         NaN
# 271396   273456  2015-12-03  Direct  Mobile               ES         NaN
# 271397   889934  2015-12-02  Direct     Web               ES         NaN
# 271400   157165  2015-11-30     SEO  Mobile               ES         NaN
# 271406   777334  2015-12-01     SEO  Mobile               ES         NaN
# 271408   548579  2015-11-30  Direct  Mobile               ES         NaN
# 271411   172885  2015-12-03  Direct     Web               ES         NaN
# 271414   486956  2015-12-02     SEO     Web               ES         NaN
# 271415   817076  2015-12-04  Direct  Mobile               ES         NaN
# 271420   325773  2015-12-03  Direct     Web            Other         NaN
# 271422   475117  2015-12-02     SEO     Web               ES         NaN
# 271424   238260  2015-12-03     SEO     Web               ES         NaN
# 271428   576115  2015-12-02  Direct     Web               ES         NaN
# 271432    18829  2015-12-03     SEO     Web               EN         NaN
# 271433   744029  2015-12-01  Direct     Web               ES         NaN
# 271434   652445  2015-12-02     SEO  Mobile               ES         NaN
# 271435   511898  2015-12-04     SEO     Web               ES         NaN
# 271436   692975  2015-12-03     SEO  Mobile               ES         NaN
# 271439   963759  2015-11-30     SEO  Mobile               ES         NaN
# 271440   177274  2015-11-30     SEO  Mobile               ES         NaN
# 271441   425010  2015-12-04     SEO     Web               ES         NaN
#
#             browser  conversion  test sex  age      country
# 2       Android_App           0     0   M   35       Mexico
# 7            Chrome           0     0   F   19  El Salvador
# 8        Iphone_App           0     0   M   27    Nicaragua
# 11          FireFox           0     0   F   28       Mexico
# 13       Iphone_App           0     0   F   45         Peru
# 14          FireFox           0     0   M   24       Mexico
# 19           Chrome           0     0   F   18    Nicaragua
# 20      Android_App           0     0   M   34         Peru
# 21          FireFox           0     0   F   21     Colombia
# 22          FireFox           0     0   F   25        Chile
# 24      Android_App           0     0   M   34      Ecuador
# 25      Android_App           0     0   F   25    Venezuela
# 26               IE           0     0   F   19       Mexico
# 32          FireFox           0     0   F   19       Mexico
# 33      Android_App           0     0   M   21     Colombia
# 37      Android_App           0     0   M   20    Venezuela
# 41      Android_App           0     0   F   18       Mexico
# 42               IE           0     0   M   48         Peru
# 47       Iphone_App           0     0   M   19       Mexico
# 48            Opera           0     0   M   24    Venezuela
# 52       Iphone_App           0     0   M   30    Guatemala
# 54           Chrome           0     0   M   21         Peru
# 57           Chrome           0     0   M   22     Colombia
# 59          FireFox           0     0   F   23    Nicaragua
# 61           Chrome           0     0   M   39       Mexico
# 62      Android_App           0     0   M   28     Colombia
# 67               IE           0     0   M   24    Nicaragua
# 68      Android_App           0     0   M   20       Mexico
# 70               IE           0     0   M   23       Mexico
# 78      Android_App           0     0   M   37     Colombia
# ...             ...         ...   ...  ..  ...          ...
# 271366       Chrome           0     0   M   22      Ecuador
# 271368       Chrome           0     0   F   25      Bolivia
# 271372           IE           0     0   F   33       Mexico
# 271374  Android_App           0     0   M   26       Mexico
# 271375           IE           0     0   F   22         Peru
# 271378  Android_App           0     0   F   26       Mexico
# 271381       Chrome           0     0   M   24    Venezuela
# 271386           IE           0     0   F   41       Mexico
# 271387           IE           0     0   M   38         Peru
# 271390           IE           0     0   M   33       Mexico
# 271396   Iphone_App           0     0   M   19       Mexico
# 271397           IE           0     0   F   30       Mexico
# 271400  Android_App           0     0   M   29        Chile
# 271406   Iphone_App           0     0   M   23    Venezuela
# 271408  Android_App           0     0   M   26     Colombia
# 271411       Chrome           0     0   F   26       Mexico
# 271414      FireFox           0     0   M   24    Venezuela
# 271415  Android_App           0     0   F   36   Costa Rica
# 271420       Chrome           0     0   M   20       Mexico
# 271422       Chrome           0     0   M   36     Colombia
# 271424           IE           0     0   M   19    Venezuela
# 271428           IE           0     0   M   37       Mexico
# 271432       Chrome           0     0   F   25      Bolivia
# 271433       Safari           0     0   F   31       Mexico
# 271434  Android_App           0     0   M   34        Chile
# 271435       Chrome           0     0   F   24       Mexico
# 271436  Android_App           0     0   M   18       Mexico
# 271439   Iphone_App           0     0   M   29       Mexico
# 271440   Iphone_App           0     0   M   33       Mexico
# 271441      FireFox           0     0   M   50       Mexico
#
# [100008 rows x 12 columns]
